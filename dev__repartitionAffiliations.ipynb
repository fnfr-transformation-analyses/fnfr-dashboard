# %%
import pandas as pd
import re

data = pd.read_csv('data/affiliationsChercheurs.csv', sep=';')
data
# Out:
#                                                 projet  concours  \
# 0    A pipeline approach for the rational design of...      2022
# 1    A pipeline approach for the rational design of...      2022
# 2    A pipeline approach for the rational design of...      2022
# 3    A pipeline approach for the rational design of...      2022
# 4    A pipeline approach for the rational design of...      2022
# ..                                                 ...       ...
# 620  TRIDENT: TRanslational Initiative to DE-risk N...      2022
# 621  TRIDENT: TRanslational Initiative to DE-risk N...      2022
# 622  TRIDENT: TRanslational Initiative to DE-risk N...      2022
# 623  TRIDENT: TRanslational Initiative to DE-risk N...      2022
# 624  TRIDENT: TRanslational Initiative to DE-risk N...      2022
#
#                  chercheur           rôle  \
# 0          Götz, Magdalena     Cocandidat
# 1         Stricker, Stefan     Cocandidat
# 2    Choque, Maria Eugenia  Collaborateur
# 3            Badea, Ildiko     Cocandidat
# 4        Bethell, Jennifer     Cocandidat
# ..                     ...            ...
# 620   Sullivan, Jacqueline     Cocandidat
# 621            Watts, Joel     Cocandidat
# 622      Williams, Sylvain  Collaborateur
# 623           Lipton, Mark  Collaborateur
# 624         Munoz, Douglas  Collaborateur
#
#                                          établissement       Pays  \
# 0    Biomedical Center, Ludwig Maximilian Universit...  Allemagne
# 1                                           LMU Munich  Allemagne
# 2                            Aymara Nation (Region 43)    Bolivie
# 3                           University of Saskatchewan     Canada
# 4                            University Health Network     Canada
# ..                                                 ...        ...
# 620                                 Western University     Canada
# 621                              University of Toronto     Canada
# 622                                  Université McGill     Canada
# 623                           Cambridge Brain Sciences     Canada
# 624  Ontario Neurodegenerative Disease Research Ini...     Canada
#
#            Région
# 0             NaN
# 1             NaN
# 2             NaN
# 3    Saskatchewan
# 4         Ontario
# ..            ...
# 620       Ontario
# 621       Ontario
# 622        Québec
# 623       Ontario
# 624       Ontario
#
# [625 rows x 7 columns]

# %%
def typeEtablissement(etablissement: str)-> str:
    text = etablissement.lower()
    if re.match(".*universit*", text):
        return 'Académique'
    if re.match(".*research institute*", text):
        return 'Académique'
    
    if re.match(".*Inc\.*", text):
        return 'Industriel'
    if re.match(".*LLC*", text):
        return 'Industriel'

    

data['type établissement'] = data['établissement'].apply(lambda x: typeEtablissement(x))

data
# Out:
#                                                 projet  concours  \
# 0    A pipeline approach for the rational design of...      2022
# 1    A pipeline approach for the rational design of...      2022
# 2    A pipeline approach for the rational design of...      2022
# 3    A pipeline approach for the rational design of...      2022
# 4    A pipeline approach for the rational design of...      2022
# ..                                                 ...       ...
# 620  TRIDENT: TRanslational Initiative to DE-risk N...      2022
# 621  TRIDENT: TRanslational Initiative to DE-risk N...      2022
# 622  TRIDENT: TRanslational Initiative to DE-risk N...      2022
# 623  TRIDENT: TRanslational Initiative to DE-risk N...      2022
# 624  TRIDENT: TRanslational Initiative to DE-risk N...      2022
#
#                  chercheur           rôle  \
# 0          Götz, Magdalena     Cocandidat
# 1         Stricker, Stefan     Cocandidat
# 2    Choque, Maria Eugenia  Collaborateur
# 3            Badea, Ildiko     Cocandidat
# 4        Bethell, Jennifer     Cocandidat
# ..                     ...            ...
# 620   Sullivan, Jacqueline     Cocandidat
# 621            Watts, Joel     Cocandidat
# 622      Williams, Sylvain  Collaborateur
# 623           Lipton, Mark  Collaborateur
# 624         Munoz, Douglas  Collaborateur
#
#                                          établissement       Pays  \
# 0    Biomedical Center, Ludwig Maximilian Universit...  Allemagne
# 1                                           LMU Munich  Allemagne
# 2                            Aymara Nation (Region 43)    Bolivie
# 3                           University of Saskatchewan     Canada
# 4                            University Health Network     Canada
# ..                                                 ...        ...
# 620                                 Western University     Canada
# 621                              University of Toronto     Canada
# 622                                  Université McGill     Canada
# 623                           Cambridge Brain Sciences     Canada
# 624  Ontario Neurodegenerative Disease Research Ini...     Canada
#
#            Région type établissement
# 0             NaN         Académique
# 1             NaN               None
# 2             NaN               None
# 3    Saskatchewan         Académique
# 4         Ontario         Académique
# ..            ...                ...
# 620       Ontario         Académique
# 621       Ontario         Académique
# 622        Québec         Académique
# 623       Ontario               None
# 624       Ontario               None
#
# [625 rows x 8 columns]
